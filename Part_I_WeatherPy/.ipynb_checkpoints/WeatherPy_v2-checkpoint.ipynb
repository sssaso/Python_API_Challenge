# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress
import csv
import json
import datetime as dt


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = url +"&units=imperial"+"&q=" + city + "&appid=" + weather_api_key

index=range(len(cities))

#Data extract from response (json object) using FOR LOOP and add to the empty list below

city_list= []
country_list = []
lat_list=[]
lon_list=[]
humidity_list=[]
temp_list=[]
maxTemp_list=[]
windSpeed_list=[]
cloudiness_list=[]
date_list=[]

for n in index:
    try:
        print(f"Making request, number {n} for {cities[n]}")
        query_url = f"{url}&units=imperial&q={cities[n]}&appid={weather_api_key}"
        response = requests.get(query_url).json()
    
        city_list.append(response['name'])
        country_list.append(response['sys']['country'])
        lat_list.append(response['coord']['lat'])
        lon_list.append(response['coord']['lon'])
        humidity_list.append(response['main']['humidity'])
        temp_list.append(response['main']['temp'])
        maxTemp_list.append(response['main']['temp_max']) 
        windSpeed_list.append(response['wind']['speed'])
        cloudiness_list.append(response['clouds']['all'])
        date_list.append(response['dt'])
    except KeyError:
        print(f"Oops, the city '{cities[n]}' doesn't exist")
    
time.sleep(2)
# Out:
# Making request, number 0 for carnarvon
# Making request, number 1 for kapaa
# Making request, number 2 for khatanga
# Making request, number 3 for tuktoyaktuk
# Making request, number 4 for puerto ayora
# Making request, number 5 for ushuaia
# Making request, number 6 for rikitea
# Making request, number 7 for armacao dos buzios
# Oops, the city 'armacao dos buzios' doesn't exist
# Making request, number 8 for teya
# Making request, number 9 for hermanus
# Making request, number 10 for esperance
# Making request, number 11 for port-gentil
# Making request, number 12 for great yarmouth
# Making request, number 13 for hoorn
# Making request, number 14 for hailar
# Making request, number 15 for alice springs
# Making request, number 16 for tessalit
# Making request, number 17 for bayir
# Making request, number 18 for yellowknife
# Making request, number 19 for paamiut
# Making request, number 20 for bull savanna
# Making request, number 21 for new norfolk
# Making request, number 22 for hobart
# Making request, number 23 for vaini
# Making request, number 24 for east london
# Making request, number 25 for arraial do cabo
# Making request, number 26 for salalah
# Making request, number 27 for horsham
# Making request, number 28 for jamestown
# Making request, number 29 for albany
# Making request, number 30 for sitka
# Making request, number 31 for hilo
# Making request, number 32 for saldanha
# Making request, number 33 for illoqqortoormiut
# Oops, the city 'illoqqortoormiut' doesn't exist
# Making request, number 34 for butaritari
# Making request, number 35 for upernavik
# Making request, number 36 for busselton
# Making request, number 37 for mahibadhoo
# Making request, number 38 for bosaso
# Making request, number 39 for ilulissat
# Making request, number 40 for kodiak
# Making request, number 41 for nome
# Making request, number 42 for duku
# Making request, number 43 for bambous virieux
# Making request, number 44 for longyearbyen
# Making request, number 45 for meyungs
# Oops, the city 'meyungs' doesn't exist
# Making request, number 46 for port alfred
# Making request, number 47 for tobol
# Making request, number 48 for guiratinga
# Making request, number 49 for ponta do sol
# Making request, number 50 for yar-sale
# Making request, number 51 for bluff
# Making request, number 52 for bacalar
# Making request, number 53 for isangel
# Making request, number 54 for cape town
# Making request, number 55 for georgetown
# Making request, number 56 for punta arenas
# Making request, number 57 for havoysund
# Making request, number 58 for sioux lookout
# Making request, number 59 for bengkulu
# Making request, number 60 for mar del plata
# Making request, number 61 for victoria
# Making request, number 62 for maymyo
# Making request, number 63 for chuy
# Making request, number 64 for hamilton
# Making request, number 65 for synya
# Making request, number 66 for xining
# Making request, number 67 for esso
# Making request, number 68 for castro
# Making request, number 69 for husavik
# Making request, number 70 for avarua
# Making request, number 71 for bathsheba
# Making request, number 72 for barentsburg
# Oops, the city 'barentsburg' doesn't exist
# Making request, number 73 for lasa
# Making request, number 74 for lebu
# Making request, number 75 for tasiilaq
# Making request, number 76 for fairbanks
# Making request, number 77 for sao joao da barra
# Making request, number 78 for vardo
# Making request, number 79 for nouakchott
# Making request, number 80 for cayenne
# Making request, number 81 for jiwani
# Making request, number 82 for boyuibe
# Making request, number 83 for qaanaaq
# Making request, number 84 for tabou
# Making request, number 85 for narsaq
# Making request, number 86 for whitianga
# Making request, number 87 for jardim
# Making request, number 88 for scarborough
# Making request, number 89 for hurricane
# Making request, number 90 for sakaiminato
# Making request, number 91 for cockburn town
# Making request, number 92 for port elizabeth
# Making request, number 93 for rehoboth
# Making request, number 94 for atuona
# Making request, number 95 for uthal
# Making request, number 96 for saskylakh
# Making request, number 97 for stantsionno-oyashinskiy
# Making request, number 98 for dikson
# Making request, number 99 for mataura
# Making request, number 100 for cidreira
# Making request, number 101 for ryotsu
# Making request, number 102 for krasnoobsk
# Making request, number 103 for airai
# Making request, number 104 for libreville
# Making request, number 105 for chokurdakh
# Making request, number 106 for destin
# Making request, number 107 for worthing
# Making request, number 108 for ahipara
# Making request, number 109 for taolanaro
# Oops, the city 'taolanaro' doesn't exist
# Making request, number 110 for san patricio
# Making request, number 111 for carmo do cajuru
# Making request, number 112 for avera
# Making request, number 113 for souillac
# Making request, number 114 for sovetskiy
# Making request, number 115 for sciacca
# Making request, number 116 for kamenskoye
# Oops, the city 'kamenskoye' doesn't exist
# Making request, number 117 for bose
# Making request, number 118 for vila franca do campo
# Making request, number 119 for torbay
# Making request, number 120 for zamora
# Making request, number 121 for rockhampton
# Making request, number 122 for the valley
# Making request, number 123 for camana
# Making request, number 124 for oistins
# Making request, number 125 for saint anthony
# Making request, number 126 for ancud
# Making request, number 127 for pangnirtung
# Making request, number 128 for mogadishu
# Making request, number 129 for kruisfontein
# Making request, number 130 for imbituba
# Making request, number 131 for saint george
# Making request, number 132 for palestina
# Making request, number 133 for xiaoweizhai
# Making request, number 134 for nelson bay
# Making request, number 135 for muros
# Making request, number 136 for norman wells
# Making request, number 137 for hirara
# Making request, number 138 for binay
# Making request, number 139 for kiama
# Making request, number 140 for nemuro
# Making request, number 141 for hede
# Making request, number 142 for ribeira grande
# Making request, number 143 for rabo de peixe
# Making request, number 144 for pevek
# Making request, number 145 for grand gaube
# Making request, number 146 for mayskiy
# Making request, number 147 for zhuozhou
# Oops, the city 'zhuozhou' doesn't exist
# Making request, number 148 for goderich
# Making request, number 149 for eureka
# Making request, number 150 for buin
# Making request, number 151 for arlit
# Making request, number 152 for leshukonskoye
# Making request, number 153 for jalu
# Making request, number 154 for faanui
# Making request, number 155 for barra do garcas
# Making request, number 156 for yomitan
# Oops, the city 'yomitan' doesn't exist
# Making request, number 157 for ternate
# Making request, number 158 for gimli
# Making request, number 159 for rurrenabaque
# Making request, number 160 for luanda
# Making request, number 161 for bodinayakkanur
# Making request, number 162 for amderma
# Oops, the city 'amderma' doesn't exist
# Making request, number 163 for povenets
# Making request, number 164 for bolungarvik
# Oops, the city 'bolungarvik' doesn't exist
# Making request, number 165 for petatlan
# Making request, number 166 for bozeman
# Making request, number 167 for adrar
# Making request, number 168 for yagodnoye
# Making request, number 169 for kuytun
# Making request, number 170 for kristiinankaupunki
# Making request, number 171 for karaul
# Oops, the city 'karaul' doesn't exist
# Making request, number 172 for anadyr
# Making request, number 173 for sambava
# Making request, number 174 for bredasdorp
# Making request, number 175 for griffith
# Making request, number 176 for namatanai
# Making request, number 177 for mamou
# Making request, number 178 for ambon
# Making request, number 179 for cervo
# Making request, number 180 for talnakh
# Making request, number 181 for alyangula
# Making request, number 182 for coquimbo
# Making request, number 183 for pochutla
# Making request, number 184 for atambua
# Making request, number 185 for camabatela
# Making request, number 186 for rio gallegos
# Making request, number 187 for mountain home
# Making request, number 188 for vaitupu
# Oops, the city 'vaitupu' doesn't exist
# Making request, number 189 for dingle
# Making request, number 190 for hithadhoo
# Making request, number 191 for mys shmidta
# Oops, the city 'mys shmidta' doesn't exist
# Making request, number 192 for seoul
# Making request, number 193 for daru
# Making request, number 194 for henties bay
# Making request, number 195 for nioro
# Making request, number 196 for sao jose da coroa grande
# Making request, number 197 for marienburg
# Making request, number 198 for erzin
# Making request, number 199 for te anau
# Making request, number 200 for epe
# Making request, number 201 for mount isa
# Making request, number 202 for umzimvubu
# Oops, the city 'umzimvubu' doesn't exist
# Making request, number 203 for karauzyak
# Oops, the city 'karauzyak' doesn't exist
# Making request, number 204 for srandakan
# Making request, number 205 for barrow
# Making request, number 206 for makakilo city
# Making request, number 207 for ponta delgada
# Making request, number 208 for bilibino
# Making request, number 209 for marzuq
# Making request, number 210 for basco
# Making request, number 211 for petropavlovsk-kamchatskiy
# Making request, number 212 for hofn
# Making request, number 213 for etchoropo
# Making request, number 214 for asau
# Making request, number 215 for tandil
# Making request, number 216 for tuatapere
# Making request, number 217 for gat
# Making request, number 218 for cabo san lucas
# Making request, number 219 for manzil salim
# Making request, number 220 for vao
# Making request, number 221 for port macquarie
# Making request, number 222 for baker city
# Making request, number 223 for bethel
# Making request, number 224 for kupang
# Making request, number 225 for gulfport
# Making request, number 226 for kangaatsiaq
# Making request, number 227 for sakakah
# Making request, number 228 for lata
# Making request, number 229 for basna
# Making request, number 230 for port lincoln
# Making request, number 231 for attawapiskat
# Oops, the city 'attawapiskat' doesn't exist
# Making request, number 232 for codrington
# Making request, number 233 for takab
# Making request, number 234 for lorengau
# Making request, number 235 for general roca
# Making request, number 236 for marawi
# Making request, number 237 for kaka
# Making request, number 238 for san policarpo
# Making request, number 239 for tiksi
# Making request, number 240 for progreso
# Making request, number 241 for lerwick
# Making request, number 242 for nha trang
# Making request, number 243 for burnie
# Making request, number 244 for samarai
# Making request, number 245 for nikolskoye
# Making request, number 246 for megion
# Making request, number 247 for ruwi
# Making request, number 248 for pingliang
# Making request, number 249 for alofi
# Making request, number 250 for pershotravneve
# Making request, number 251 for pakwach
# Oops, the city 'pakwach' doesn't exist
# Making request, number 252 for kununurra
# Making request, number 253 for panalingaan
# Making request, number 254 for severo-kurilsk
# Making request, number 255 for mehamn
# Making request, number 256 for cascais
# Making request, number 257 for stonewall
# Making request, number 258 for kudahuvadhoo
# Making request, number 259 for shenjiamen
# Making request, number 260 for guerrero negro
# Making request, number 261 for biak
# Making request, number 262 for belushya guba
# Oops, the city 'belushya guba' doesn't exist
# Making request, number 263 for egvekinot
# Making request, number 264 for beringovskiy
# Making request, number 265 for milkovo
# Making request, number 266 for faya
# Making request, number 267 for nizhneyansk
# Oops, the city 'nizhneyansk' doesn't exist
# Making request, number 268 for bandarbeyla
# Making request, number 269 for broome
# Making request, number 270 for korla
# Making request, number 271 for rawson
# Making request, number 272 for saint-philippe
# Making request, number 273 for pascagoula
# Making request, number 274 for champerico
# Making request, number 275 for durban
# Making request, number 276 for erenhot
# Making request, number 277 for christchurch
# Making request, number 278 for semey
# Making request, number 279 for boffa
# Making request, number 280 for naze
# Making request, number 281 for thunder bay
# Making request, number 282 for yilan
# Making request, number 283 for hami
# Making request, number 284 for emba
# Making request, number 285 for kalomo
# Oops, the city 'kalomo' doesn't exist
# Making request, number 286 for rocha
# Making request, number 287 for salinopolis
# Making request, number 288 for millinocket
# Making request, number 289 for klyuchi
# Making request, number 290 for kangaba
# Making request, number 291 for thompson
# Making request, number 292 for likasi
# Making request, number 293 for fallon
# Making request, number 294 for daud khel
# Making request, number 295 for hambantota
# Making request, number 296 for cairns
# Making request, number 297 for provideniya
# Making request, number 298 for cherskiy
# Making request, number 299 for srednekolymsk
# Making request, number 300 for bababe
# Oops, the city 'bababe' doesn't exist
# Making request, number 301 for sao felix do xingu
# Making request, number 302 for las lomas
# Making request, number 303 for lavrentiya
# Making request, number 304 for solnechnyy
# Making request, number 305 for vanderhoof
# Making request, number 306 for koutsouras
# Making request, number 307 for vrangel
# Making request, number 308 for hobyo
# Making request, number 309 for abha
# Making request, number 310 for carbondale
# Making request, number 311 for ferme-neuve
# Making request, number 312 for amapa
# Making request, number 313 for placido de castro
# Making request, number 314 for kisangani
# Making request, number 315 for yerbogachen
# Making request, number 316 for sofiysk
# Oops, the city 'sofiysk' doesn't exist
# Making request, number 317 for chulym
# Making request, number 318 for iqaluit
# Making request, number 319 for shumyachi
# Making request, number 320 for santa fe
# Making request, number 321 for yantarnyy
# Making request, number 322 for sinop
# Making request, number 323 for touros
# Making request, number 324 for coihaique
# Making request, number 325 for miri
# Making request, number 326 for tuggurt
# Oops, the city 'tuggurt' doesn't exist
# Making request, number 327 for kamwenge
# Making request, number 328 for yuli
# Making request, number 329 for mahebourg
# Making request, number 330 for koygorodok
# Making request, number 331 for sansai
# Oops, the city 'sansai' doesn't exist
# Making request, number 332 for tromso
# Making request, number 333 for rivadavia
# Making request, number 334 for zima
# Making request, number 335 for ballina
# Making request, number 336 for goundam
# Making request, number 337 for cochrane
# Making request, number 338 for moron
# Making request, number 339 for nyurba
# Making request, number 340 for burns lake
# Making request, number 341 for necochea
# Making request, number 342 for high level
# Making request, number 343 for sabang
# Making request, number 344 for college
# Making request, number 345 for magaria
# Making request, number 346 for bay roberts
# Making request, number 347 for meulaboh
# Making request, number 348 for gizo
# Making request, number 349 for soure
# Making request, number 350 for bako
# Making request, number 351 for mayumba
# Making request, number 352 for inhambane
# Making request, number 353 for kahului
# Making request, number 354 for corrente
# Making request, number 355 for lagoa
# Making request, number 356 for sam chuk
# Making request, number 357 for kodinar
# Making request, number 358 for bacolod
# Making request, number 359 for guarapari
# Making request, number 360 for saint-francois
# Making request, number 361 for nanortalik
# Making request, number 362 for pokaran
# Making request, number 363 for aragarcas
# Making request, number 364 for lompoc
# Making request, number 365 for kurilsk
# Making request, number 366 for sentyabrskiy
# Oops, the city 'sentyabrskiy' doesn't exist
# Making request, number 367 for waddan
# Making request, number 368 for ailigandi
# Making request, number 369 for loughrea
# Making request, number 370 for aksu
# Making request, number 371 for bani walid
# Making request, number 372 for saleaula
# Oops, the city 'saleaula' doesn't exist
# Making request, number 373 for lolua
# Oops, the city 'lolua' doesn't exist
# Making request, number 374 for novobirilyussy
# Making request, number 375 for sehithwa
# Making request, number 376 for san ramon
# Making request, number 377 for haines junction
# Making request, number 378 for jiexiu
# Making request, number 379 for harper
# Making request, number 380 for harrogate
# Making request, number 381 for chagda
# Oops, the city 'chagda' doesn't exist
# Making request, number 382 for chicama
# Making request, number 383 for matinha
# Making request, number 384 for clyde river
# Making request, number 385 for shishou
# Making request, number 386 for garowe
# Making request, number 387 for bagdarin
# Making request, number 388 for dali
# Making request, number 389 for kaitangata
# Making request, number 390 for san jose
# Making request, number 391 for mian channun
# Making request, number 392 for ituni
# Oops, the city 'ituni' doesn't exist
# Making request, number 393 for berlevag
# Making request, number 394 for huarmey
# Making request, number 395 for nopaltepec
# Making request, number 396 for kodinsk
# Making request, number 397 for toliary
# Oops, the city 'toliary' doesn't exist
# Making request, number 398 for sinkat
# Oops, the city 'sinkat' doesn't exist
# Making request, number 399 for marquette
# Making request, number 400 for vanavara
# Making request, number 401 for ust-kuyga
# Making request, number 402 for sobral
# Making request, number 403 for samusu
# Oops, the city 'samusu' doesn't exist
# Making request, number 404 for koscian
# Making request, number 405 for geraldton
# Making request, number 406 for sokolo
# Making request, number 407 for arman
# Making request, number 408 for cabatuan
# Making request, number 409 for bereda
# Making request, number 410 for gamba
# Making request, number 411 for kutum
# Making request, number 412 for peniche
# Making request, number 413 for baependi
# Making request, number 414 for ubrique
# Making request, number 415 for yuryuzan
# Making request, number 416 for abeche
# Making request, number 417 for walvis bay
# Making request, number 418 for jujuy
# Oops, the city 'jujuy' doesn't exist
# Making request, number 419 for burica
# Oops, the city 'burica' doesn't exist
# Making request, number 420 for winnemucca
# Making request, number 421 for tumannyy
# Oops, the city 'tumannyy' doesn't exist
# Making request, number 422 for magway
# Making request, number 423 for nueve de julio
# Making request, number 424 for petukhovo
# Making request, number 425 for pangai
# Making request, number 426 for katangli
# Making request, number 427 for kencong
# Making request, number 428 for puerto leguizamo
# Making request, number 429 for yasnyy
# Making request, number 430 for tautira
# Making request, number 431 for tyrma
# Making request, number 432 for azimur
# Oops, the city 'azimur' doesn't exist
# Making request, number 433 for kamaishi
# Making request, number 434 for auki
# Making request, number 435 for deep river
# Making request, number 436 for manta
# Making request, number 437 for puerto carreno
# Making request, number 438 for luderitz
# Making request, number 439 for marcona
# Oops, the city 'marcona' doesn't exist
# Making request, number 440 for verkhoyansk
# Making request, number 441 for thinadhoo
# Making request, number 442 for catacocha
# Making request, number 443 for aransas pass
# Making request, number 444 for at-bashi
# Making request, number 445 for mongo
# Making request, number 446 for richards bay
# Making request, number 447 for port hedland
# Making request, number 448 for koster
# Making request, number 449 for bireun
# Making request, number 450 for zaragoza
# Making request, number 451 for dunedin
# Making request, number 452 for tura
# Making request, number 453 for raudeberg
# Making request, number 454 for gilbues
# Making request, number 455 for dudinka
# Making request, number 456 for vila do maio
# Making request, number 457 for micheweni
# Making request, number 458 for sorong
# Making request, number 459 for zhuhai
# Making request, number 460 for northam
# Making request, number 461 for zhenlai
# Making request, number 462 for kavieng
# Making request, number 463 for aklavik
# Making request, number 464 for neuquen
# Making request, number 465 for kiunga
# Making request, number 466 for kudchi
# Oops, the city 'kudchi' doesn't exist
# Making request, number 467 for port hardy
# Making request, number 468 for mikhaylovka
# Making request, number 469 for kortkeros
# Making request, number 470 for road town
# Making request, number 471 for fortuna
# Making request, number 472 for veraval
# Making request, number 473 for bilma
# Making request, number 474 for baruun-urt
# Making request, number 475 for half moon bay
# Making request, number 476 for sorland
# Making request, number 477 for ust-tsilma
# Making request, number 478 for aketi
# Making request, number 479 for ucluelet
# Making request, number 480 for hurghada
# Making request, number 481 for san isidro
# Making request, number 482 for tual
# Making request, number 483 for la ronge
# Making request, number 484 for jarvakandi
# Making request, number 485 for the pas
# Making request, number 486 for lazaro cardenas
# Making request, number 487 for arona
# Making request, number 488 for eyl
# Making request, number 489 for palabuhanratu
# Oops, the city 'palabuhanratu' doesn't exist
# Making request, number 490 for artyk
# Oops, the city 'artyk' doesn't exist
# Making request, number 491 for churapcha
# Making request, number 492 for tatarsk
# Making request, number 493 for gidole
# Making request, number 494 for marystown
# Making request, number 495 for katherine
# Making request, number 496 for juegang
# Making request, number 497 for caconda
# Making request, number 498 for grand river south east
# Oops, the city 'grand river south east' doesn't exist
# Making request, number 499 for gao
# Making request, number 500 for pampa
# Making request, number 501 for kralendijk
# Making request, number 502 for yuancheng
# Making request, number 503 for nyagan
# Making request, number 504 for tazovskiy
# Making request, number 505 for leningradskiy
# Making request, number 506 for songkhla
# Making request, number 507 for zyryanka
# Making request, number 508 for khani
# Making request, number 509 for majene
# Making request, number 510 for binga
# Making request, number 511 for port lavaca
# Making request, number 512 for klaksvik
# Making request, number 513 for vostok
# Making request, number 514 for saint peters
# Making request, number 515 for alibag
# Making request, number 516 for talaya
# Making request, number 517 for san matias
# Making request, number 518 for taoudenni
# Making request, number 519 for basar
# Making request, number 520 for port-cartier
# Making request, number 521 for umm lajj
# Making request, number 522 for bucerias
# Making request, number 523 for beasain
# Making request, number 524 for puerto del rosario
# Making request, number 525 for karpathos
# Making request, number 526 for laguna
# Making request, number 527 for valleyview
# Making request, number 528 for whitehorse
# Making request, number 529 for okhotsk
# Making request, number 530 for porto novo
# Making request, number 531 for nishihara
# Making request, number 532 for pouembout
# Making request, number 533 for palmer
# Making request, number 534 for fort-shevchenko
# Making request, number 535 for aykhal
# Making request, number 536 for grindavik
# Making request, number 537 for tarudant
# Oops, the city 'tarudant' doesn't exist
# Making request, number 538 for yelyzavethradka
# Making request, number 539 for sorvag
# Oops, the city 'sorvag' doesn't exist
# Making request, number 540 for zheleznodorozhnyy
# Making request, number 541 for kailua
# Making request, number 542 for honningsvag
# Making request, number 543 for karratha
# Making request, number 544 for cranbrook
# Making request, number 545 for lakselv
# Making request, number 546 for waipawa
# Making request, number 547 for ndele
# Making request, number 548 for aksarka
# Making request, number 549 for beloha
# Making request, number 550 for ruatoria
# Oops, the city 'ruatoria' doesn't exist
# Making request, number 551 for grand centre
# Oops, the city 'grand centre' doesn't exist
# Making request, number 552 for verkhnetulomskiy
# Making request, number 553 for vestmanna
# Making request, number 554 for bubaque
# Making request, number 555 for xudat
# Making request, number 556 for takoradi
# Making request, number 557 for brae
# Making request, number 558 for khandyga
# Making request, number 559 for pingdu
# Making request, number 560 for palauig
# Making request, number 561 for kavaratti
# Making request, number 562 for zomba
# Making request, number 563 for zaozerne
# Making request, number 564 for banda aceh
# Making request, number 565 for key largo
# Making request, number 566 for kingman
# Making request, number 567 for kindu
# Making request, number 568 for gaogou
# Making request, number 569 for presidencia roque saenz pena
# Making request, number 570 for bowen
# Making request, number 571 for santa barbara
# Making request, number 572 for sept-iles
# Making request, number 573 for idrinskoye
# Making request, number 574 for turukhansk
# Making request, number 575 for garden city
# Making request, number 576 for buariki
# Oops, the city 'buariki' doesn't exist
# Making request, number 577 for urumqi
# Making request, number 578 for leh
# Making request, number 579 for altamira
# Making request, number 580 for troitskoye
# Making request, number 581 for shaowu
# Making request, number 582 for urucara
# Making request, number 583 for orapa
# Making request, number 584 for puerto quijarro
# Making request, number 585 for qianguo
# Making request, number 586 for mattru
# Making request, number 587 for jiuquan
# Making request, number 588 for kalmunai
# Making request, number 589 for chiang rai
# Making request, number 590 for rawannawi
# Oops, the city 'rawannawi' doesn't exist
# Making request, number 591 for zasheyek
# Making request, number 592 for acapulco
# Making request, number 593 for warqla
# Oops, the city 'warqla' doesn't exist
# Making request, number 594 for little current
# Making request, number 595 for yulara
# Making request, number 596 for saint-avold
# Making request, number 597 for beltinci
# Making request, number 598 for ksenyevka
# Oops, the city 'ksenyevka' doesn't exist
# Making request, number 599 for limbang
# Making request, number 600 for tiznit
# Making request, number 601 for oum hadjer
# Making request, number 602 for koumac
# Making request, number 603 for sault sainte marie
# Making request, number 604 for prince rupert
# Making request, number 605 for ermelo
# Making request, number 606 for gladstone
# Making request, number 607 for rantoul
# Making request, number 608 for praia da vitoria
# Making request, number 609 for tornio
# Making request, number 610 for havre-saint-pierre
# Making request, number 611 for iquique
# Making request, number 612 for arrifes
# Making request, number 613 for la baule-escoublac
# Making request, number 614 for pushchino
# Making request, number 615 for dzilam gonzalez
# Making request, number 616 for mangai
# Making request, number 617 for heze
# Making request, number 618 for rayagada
# Making request, number 619 for ribeira brava

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_id = list(range(len(city_list)))
w_dict={"City ID":city_id, "City":city_list, "Country":country_list, "Lat":lat_list,"Lng":lon_list,
        "Humidity":humidity_list,"Temp":temp_list,"Max Temp":maxTemp_list,"Wind Speed":windSpeed_list,
        "Cloudiness":cloudiness_list,"Date":date_list}
city_data=pd.DataFrame(w_dict).set_index(['City ID'])
city_data.head()
# Out:
#                  City Country    Lat     Lng  Humidity   Temp  Max Temp  \
# City ID
# 0           Carnarvon      AU -24.87  113.63        72  59.00     59.00
# 1               Kapaa      US  22.08 -159.32        94  74.89     77.00
# 2            Khatanga      RU  71.97  102.50        61  52.07     52.07
# 3         Tuktoyaktuk      CA  69.45 -133.04        93  44.60     44.60
# 4        Puerto Ayora      EC  -0.74  -90.35        51  77.85     84.20
#
#          Wind Speed  Cloudiness        Date
# City ID
# 0             11.41           0  1592508912
# 1             14.99          90  1592508630
# 2             11.88          55  1592509108
# 3             10.29          90  1592509039
# 4              9.17          64  1592508639

# %%
city_data.count()
# Out:
# City          571
# Country       571
# Lat           571
# Lng           571
# Humidity      571
# Temp          571
# Max Temp      571
# Wind Speed    571
# Cloudiness    571
# Date          571
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data.describe()
# Out:
#               Lat         Lng    Humidity        Temp    Max Temp  Wind Speed  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean    21.757741   17.814939   68.302977   68.110175   68.582382    8.148914
# std     33.208033   91.279751   21.983989   15.200926   15.337079    5.571296
# min    -54.800000 -179.170000    1.000000   30.540000   30.540000    0.200000
# 25%     -3.720000  -60.570000   55.000000   57.460000   57.715000    4.470000
# 50%     26.180000   20.830000   74.000000   69.350000   69.800000    6.930000
# 75%     50.090000   99.505000   84.500000   80.440000   80.600000   10.435000
# max     78.220000  179.320000  100.000000  105.400000  105.400000   47.200000
#
#        Cloudiness          Date
# count  571.000000  5.710000e+02
# mean    50.446585  1.592509e+09
# std     37.957250  2.149130e+02
# min      0.000000  1.592509e+09
# 25%     12.500000  1.592509e+09
# 50%     47.000000  1.592509e+09
# 75%     90.000000  1.592509e+09
# max    100.000000  1.592509e+09

# %%
#  Get the indices of cities that have humidity over 100%.
city_data.loc[city_data["Humidity"] > 100, ['City']]
# Out:
# Empty DataFrame
# Columns: [City]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_data.drop(city_data[city_data["Humidity"] > 100].index)
clean_city_data.head()
# Out:
#                  City Country    Lat     Lng  Humidity   Temp  Max Temp  \
# City ID
# 0           Carnarvon      AU -24.87  113.63        72  59.00     59.00
# 1               Kapaa      US  22.08 -159.32        94  74.89     77.00
# 2            Khatanga      RU  71.97  102.50        61  52.07     52.07
# 3         Tuktoyaktuk      CA  69.45 -133.04        93  44.60     44.60
# 4        Puerto Ayora      EC  -0.74  -90.35        51  77.85     84.20
#
#          Wind Speed  Cloudiness        Date
# City ID
# 0             11.41           0  1592508912
# 1             14.99          90  1592508630
# 2             11.88          55  1592509108
# 3             10.29          90  1592509039
# 4              9.17          64  1592508639

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv
city_data.to_csv("city_data.csv")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
w_date=dt.date.fromtimestamp(1592491096).strftime('%Y-%m-%d')
w_date
# Out:
# '2020-06-18'

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# scatter plot 
plt.figure(figsize=(8,5))
plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp"],marker="o",facecolors="lightgreen",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Temperature(2020-06-18)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.grid(True,alpha=0.3)
plt.show()

# Save the figure
plt.savefig("Lat_vs_Temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# scatter plot 
plt.figure(figsize=(8,5))
plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"],marker="o",facecolors="lightgreen",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Humidity(2020-06-18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.grid(True,alpha=0.3)
plt.show()

# Save the figure
plt.savefig("Lat_vs_Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# scatter plot 
plt.figure(figsize=(8,5))
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"],marker="o",facecolors="lightgreen",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Cloudiness(2020-06-18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.grid(True,alpha=0.3)
plt.show()

# Save the figure
plt.savefig("Lat_vs_Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# scatter plot 
plt.figure(figsize=(8,5))
plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"],marker="o",facecolors="lightgreen",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Wind Speed(2020-06-18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.grid(True,alpha=0.3)
plt.show()

# Save the figure
plt.savefig("Lat_vs_Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
n_hemi = clean_city_data.loc[clean_city_data['Lat']>0]
s_hemi = clean_city_data.loc[clean_city_data['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
y_values=n_hemi['Max Temp']
x_values=n_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,2)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Max Temperatre (F) (2020-06-18)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (5,40), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("nH_lat_vs_maxTemp.png")
# Out:
# Y = -0.56X + 91.4
# R-squared is : 0.5161

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
y_values=s_hemi['Max Temp']
x_values=s_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,2)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Max Temperatre (F) (2020-06-18)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (-20,35), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("sH_lat_vs_maxTemp.png")
# Out:
# Y = 0.81X + 83.64
# R-squared is : 0.6358

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Humidity vs. latitude
y_values=n_hemi['Humidity']
x_values=n_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,2)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Humidity (%) (2020-06-18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (50,18), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("nH_lat_vs_Humidity.png")
# Out:
# Y = 0.04X + 65.36
# R-squared is : 0.0012

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on Humidity vs. latitude
y_values=s_hemi['Humidity']
x_values=s_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,2)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Humidity (%) (2020-06-18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (-20,30), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("sH_lat_vs_Humidity.png")
# Out:
# Y = -0.07X + 70.37
# R-squared is : 0.0025

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Perform a linear regression on Humidity vs. latitude
y_values=n_hemi['Cloudiness']
x_values=n_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,2)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Cloudiness (%) (2020-06-18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (5,10), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("nH_lat_vs_Cloudiness.png")
# Out:
# Y = -0.1X + 55.91
# R-squared is : 0.0032

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Perform a linear regression on Humidity vs. latitude
y_values=s_hemi['Cloudiness']
x_values=s_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,2)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Cloudiness (%) (2020-06-18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (-55,10), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("sH_lat_vs_Cloudiness.png")
# Out:
# Y = 0.03X + 47.51
# R-squared is : 0.0001

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Perform a linear regression on Humidity vs. latitude
y_values=n_hemi['Wind Speed']
x_values=n_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq="Y = " + str(round(slope,3)) + "X + "+str(round(intercept,2))
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Wind Speed(mph) (2020-06-18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (50,35), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("nH_lat_vs_windSpeed.png")
# Out:
# Y = -0.004X + 8.4
# R-squared is : 0.0002

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Perform a linear regression on Humidity vs. latitude
y_values=s_hemi['Wind Speed']
x_values=s_hemi['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

line_eq=f"Y = {str(round(slope,2))}X + {str(round(intercept,2))}"
print(line_eq)
print(f"R-squared is : {round(rvalue**2,4)}") 

plt.figure(figsize=(8,5))
# scatter plot 
plt.scatter(x_values,y_values,marker="o",facecolors="lightblue",alpha=0.8, edgecolors="black")

#x=np.arange(-90,90,10)
plt.title("City Latitude vs Wind Speed(mph) (2020-06-18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
#plt.xticks(x)
plt.annotate(line_eq, (-50,20), fontsize=13, color='blue')
plt.grid(True,alpha=0.3)

plt.plot(x_values,regress_values,color='blue')

plt.show()

# Save the figure
plt.savefig("sH_lat_vs_windSpeed.png")
# Out:
# Y = -0.02X + 7.57
# R-squared is : 0.0023
